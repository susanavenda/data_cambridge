# %% [markdown]
# <a href="https://colab.research.google.com/github/susanavenda/data_cambridge/blob/main/Venda_Susana_CAM_C301_Week_4and5_Topic_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **First things first** - please go to 'File' and select 'Save a copy in Drive' so that you have your own version of this activity set up and ready to use.
# Remember to update the portfolio index link to your own work once completed!

# %% [markdown]
# # Topic project 4.1 Applying NLP for topic modelling in a real-life context
#
# **Welcome to your topic project: Applying NLP for topic modelling in a real-life context**
#
# In this project, you will bridge the gap between theory and practical application by developing automated topic modelling tools tailored to a specific industry context.
#
#
# Applying NLP for topic modelling is crucial for data analysis in business because it enables companies to identify and understand key themes and patterns within large volumes of text data. This efficiency allows businesses to extract essential insights and trends without manually sifting through extensive documents. Automated topic modelling helps businesses make informed decisions faster, which helps to improve productivity and gain a competitive edge. Additionally, it supports better information management by uncovering underlying topics in reports, emails, customer feedback, and market research, which enhances overall business intelligence and strategic planning.
#
#
#
#
# Please set aside approximately **19 hours** to complete the topic project by **Thursday, 22 August at 5 p.m. (UK Time)**.
#
# <br>
#
# ## **Business context**
#
# The PureGym Group, founded in 2008, has approximately 2 million members and 600 gyms across the world (particularly in the UK, Denmark, and Switzerland). As one of the world’s largest value fitness operators, PureGym appeals to a broad range of customers by offering high-quality, low-cost, and flexible fitness facilities. The company’s customer-centric proposition – affordable membership fees, no fixed-term contracts, and 24/7 access to high-quality gyms – differentiates it from more traditional gyms and elevates it as a market leader within this space.
#
# This focus on the customer is centred on wanting to understand what motivates members to join and what factors influence their behaviours once they have joined. Understanding how to leverage innovative technology to influence, improve, and simplify their experience allows PureGym to foster an open, welcoming, and diverse environment for its members while maintaining the value proposition that PureGym is built upon.
#
# With the shift in focus to value-for-money memberships across the gym industry, PureGym seeks to achieve its mission of ‘inspiring a healthier world by providing members with affordable access to the benefits being healthy can offer’.
#
#
# <br></br>
#
# ## **Objective**
#
# By the end of this topic project, you will have analysed PureGym's review data to uncover key drivers that provide actionable insights for enhancing customer experience.
#
# In the Notebook, you will:
#
# - Use two data sets containing customer reviews from Google and Trustpilot.
# - Perform basic level analysis by finding the frequently used words in both data sets.
# - Generate a wordcloud to visualise the most frequently used words in the reviews.
# - Apply BERTopic for topic modelling, keeping track of gym locations, to identify common topics and words in the negative reviews.
# - Identify the locations that have the most negative reviews.
# - Use the built-in visualisation functions in BERTopic to cluster and visually represent the topics and words in these reviews, thereby helping to identify specific themes from the reviews.
# - Conduct a comparison with Gensim’s LDA model to validate the topic modelling results.
# - Perform emotion analysis to identify the emotions associated with customer reviews.
# - Filter out angry reviews and apply BERTopic to discover prevalent topics and words being discussed these negative reviews.
# - Leverage the multi-purpose capability of the state-of-the-art Falcon-7b-instruct model, with the help of prompts, to identify top topics in each review.
# - Use a different prompt with the Falcon-7b-instruct model to further generate suggestions for improvements for PureGym, based on the top topics identified from the negative reviews.
#
#
# You will also write a report summarising the results of your findings and recommendations.
#
#
# <br></br>
#
# ## **Assessment criteria**
# By completing this project, you will be able to provide evidence that you can:
#
# - Investigate real-world data to find potential trends for deeper investigation.
# -Preprocess and refine textual data for visualisations.
# -Apply topic modelling using various techniques.
# -Apply emotion analysis using BERT.
# -Evaluate the outcomes of your investigation.
# -Communicate actionable insights.
#
#
#
# <br></br>
#
# ## **Project guidance**
#
# **Import packages and data:**
# 1. 1. Import the data set with the provided URL:
#   - Data set's Drive link: https://drive.google.com/drive/folders/1azch13dtGeAkbnEjqeoyl3nU9jheojU4
# 2. Import the data file **Google_12_months.xlsx** into a dataframe.
# 3. Import the data file **Trustpilot_12_months.xslx** into a dataframe.
# 4. Remove any rows with missing values in the Comment column (Google review) and Review Content column (Trustpilot).
#
#
# **Conducting initial data investigation:**
#
# 1. - Find the number of unique locations in the Google data set.
#
#   - Find the number of unique locations in the Trustpilot data set.
#
#   - Use Club's Name for the Google data set.
#
#   - Use Location Name for the Trustpilot data set.
# 2. Find the number of common locations between the Google data set and the Trustpilot data set.
# 3. Perform preprocessing of the data – change to lower case, remove stopwords using NLTK, and remove numbers.
# 4. Tokenise the data using word_tokenize from NLTK.
# 5. Find the frequency distribution of the words from each data set's reviews separately. You can use nltk.freqDist.
# 6. Plot a histogram/bar plot showing the top 10 words from each data set.
# 7. Use the wordcloud library on the cleaned data and plot the word cloud.
# 8. Create a new dataframe by filtering out the data to extract only the negative reviews from both data sets.
#
#   • For Google reviews, overall scores < 3 can be considered negative scores.
#
#   • For Trustpilot reviews, stars < 3 can be considered negative scores.
#
#   Repeat the frequency distribution and wordcloud steps on the filtered data consisting of only negative reviews.
#
#
# **Conducting initial topic modelling:**
#
# 1. With the data frame created in the previous step:
#
#   • Filter out the reviews that are from the locations common to both data sets.
#
#   • Merge the reviews to form a new list.
#
# 2. Preprocess this data set. Use BERTopic on this cleaned data set.
# 3. Output: List out the top topics along with their document frequencies.
# 4. For the top 2 topics, list out the top words.
# 5. Show an interactive visualisation of the topics to identify the cluster of topics and to understand the intertopic distance map.
# 6. Show a barchart of the topics, displaying the top 5 words in each topic.
# 7. Plot a heatmap, showcasing the similarity matrix.
# 8. For 10 clusters, provide a brief description in the Notebook of the topics they comprise of along with the general theme of the cluster, evidenced by the top words within each cluster's topics.
#
# **Performing further data investigation:**
#
# 1. List out the top 20 locations with the highest number of negative reviews. Do this separately for Google and Trustpilot's reviews, and comment on the result. Are the locations roughly similar in both data sets?
# 2. Merge the 2 data sets using Location Name and Club's Name.
#
#   Now, list out the following:
#
#   • Locations
#
#   • Number of Trustpilot reviews for this location
#
#   • Number of Google reviews for this location
#
#   • Total number of reviews for this location (sum of Google reviews and Trustpilot reviews)
#
#   Sort based on the total number of reviews.
# 3. For the top 30 locations, redo the word frequency and word cloud. Comment on the results, and highlight if the results are different from the first run.
# 4. For the top 30 locations, combine the reviews from Google and Trustpilot and run them through BERTopic.
#
#   Comment on the following:
#
#   • Are the results any different from the first run of BERTopic?
#
#   • If so, what has changed?
#
#   • Are there any additional insights compared to the first run?
#
# **Conducting emotion analysis:**
#
# 1. Import the BERT model bhadresh-savani/bert-base-uncased-emotion from Hugging Face, and set up a pipeline for text classification.
# 2. With the help of an example sentence, run the model and display the different emotion classifications that the model outputs.
# 3. Run this model on both data sets, and capture the top emotion for each review.
# 4. Use a bar plot to show the top emotion distribution for all negative reviews in both data sets.
# 5. Extract all the negative reviews (from both data sets) where anger is top emotion.
# 6. Run BERTopic on the output of the previous step.
# 7. Visualise the clusters from this run. Comment on whether it is any different from the previous runs, and whether it is possible to narrow down the primary issues that have led to an angry review.
#
# **Using a large language model from Hugging Face:**
#
# 1. Load the following model: tiiuae/falcon-7b-instruct. Set the pipeline for text generation and a max length of 1,000 for each review.
# 2. Add the following prompt to every review, before passing it on to the model: **In the following customer review, pick out the main 3 topics. Return them in a numbered list format, with each one on a new line.**
#
#   Run the model.
#
#   Note: If the execution time is too high, you can use a subset of the bad reviews (instead of the full set) to run this model.
# 3. The output of the model will be the top 3 topics from each review. Append each of these topics from each review to create a comprehensive list.
# 4. Use this list as input to run BERTopic again.
# 5. Comment about the output of BERTopic. Highlight any changes, improvements, and if any further insights have been obtained.
# 6. Use the comprehensive list from Step 3.
#
#   Pass it to the model as the input, but pre-fix the following to the prompt: **For the following text topics obtained from negative customer reviews, can you give some actionable insights that would help this gym company?**
#
#   Run the Falcon-7b-Instruct model.
# 7. List the output, ideally in the form of suggestions, that the company can employ to address customer concerns.
#
# **Using Gensim:**
# 1. Perform the preprocessing required to run the LDA model from Gensim. Use the list of negative reviews (combined Google and Trustpilot reviews).
# 2. Using Gensim, perform LDA on the tokenised data. Specify the number of topics = 10.
# 3. Show the visualisations of the topics, displaying the distance maps and the bar chart listing out the most salient terms.
# 4. Comment on the output and whether it is similar to other techniques, or whether any extra insights were obtained.
#
# **Report:**
# 1. Document your approach and major inferences from the data analysis.
# 2. When you have completed the project:
#   - Download your completed Notebook as an IPYNB (Jupyter Notebook) or PY (Python) file. Save the file as follows: **LastName_FirstName_CAM_C301_Week_4and5_Topic_project.ipynb**.
#   - Prepare a detailed report (between 800–1,000 words) that includes:
#     - an overview of your approach
#     - a description of your analysis
#     - an explanation of the insights you identified
#     - a summary of the comments requested in earlier steps
#     - final insights, based on the output obtained from the various models employed
#   - Save the document as a PDF named according to the following convention: **LastName_FirstName_CAM_C301_Week_4and5_Topic_project.pdf**.
#   - Submit your Notebook and PDF document by **Thursday, 22 August at 5 p.m. (UK Time)**.
#
#
# <br></br>
# > **Declaration**
# >
# > By submitting your project, you indicate that the work is your own and has been created with academic integrity. Refer to the Cambridge plagiarism regulations.

# %% [markdown]
# # Stage 0 — Setup

# %%
##@title 0.1 Install dependencies
# !pip install bertopic --quiet
# !pip install gensim --quiet
# !pip install wordcloud --quiet
# !pip install nltk --quiet
# !pip install transformers accelerate --quiet
# !pip install pyldavis --quiet
# !pip install plotly --quiet

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# /opt/homebrew/Cellar/python@3.12/3.12.13_4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=91733) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# /opt/homebrew/Cellar/python@3.12/3.12.13_4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=91733) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# /opt/homebrew/Cellar/python@3.12/3.12.13_4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=91733) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# ...

# %%
## @title 0.2 Imports, palette and display helpers
import re
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
from wordcloud import WordCloud

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import FreqDist

from IPython.display import display, HTML

warnings.filterwarnings('ignore')
pio.renderers.default = "colab"

# ── Palette & theme (same as CAM_C201 mini-project) ───────────────────────
DARK_BG   = "#0F172A"
CARD_BG   = "#1E293B"
BORDER    = "#334155"
TEXT_PRI  = "#F1F5F9"
TEXT_SEC  = "#94A3B8"
TEAL      = "#0EA5E9"
GREEN     = "#22C55E"
AMBER     = "#F59E0B"
RED       = "#EF4444"
PURPLE    = "#A78BFA"

PALETTE   = [TEAL, GREEN, AMBER, RED, PURPLE, "#FB923C", "#34D399"]
STOP_WORDS = set(stopwords.words('english'))

# ── Display helpers ────────────────────────────────────────────────────────
_fig_counter, _table_counter = [0], [0]

def _show_fig(fig, title=""):
    _fig_counter[0] += 1
    label = f"Figure {_fig_counter[0]}" + (f" — {title}" if title else "")
    fig.update_layout(
        plot_bgcolor=CARD_BG, paper_bgcolor=DARK_BG,
        font_color=TEXT_PRI, font_family="Inter, DejaVu Sans",
        title_font_color=TEXT_PRI,
        xaxis=dict(gridcolor=BORDER, linecolor=BORDER),
        yaxis=dict(gridcolor=BORDER, linecolor=BORDER),
        margin=dict(l=40, r=20, t=50, b=40),
    )
    display(HTML(f'<p style="font-family:Inter,sans-serif;font-size:11px;color:{TEXT_SEC};margin:8px 0 2px">{label}</p>'))
    display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))

def display_table(df, title="", max_rows=30):
    _table_counter[0] += 1
    label = f"Table {_table_counter[0]}" + (f" — {title}" if title else "")
    cols = list(df.columns)
    header = "".join(f'<th style="padding:8px 14px;text-align:left;color:{TEAL};font-weight:600;'
                      f'border-bottom:1px solid {BORDER};font-family:Inter,sans-serif;font-size:12px">{c}</th>' for c in cols)
    rows_html = ""
    for i, (_, row) in enumerate(df.head(max_rows).iterrows()):
        bg = CARD_BG if i % 2 == 0 else "#253047"
        cells_html = "".join(f'<td style="padding:7px 14px;font-family:Inter,sans-serif;font-size:12px;'
                              f'color:{TEXT_PRI}">{v}</td>' for v in row.values)
        rows_html += f'<tr style="background:{bg}">{cells_html}</tr>'
    display(HTML(f'''
        <p style="font-family:Inter,sans-serif;font-size:11px;color:{TEXT_SEC};margin:12px 0 4px">{label}</p>
        <div style="overflow-x:auto;border-radius:8px;border:1px solid {BORDER}">
          <table style="border-collapse:collapse;width:100%;background:{DARK_BG}">
            <thead><tr>{header}</tr></thead><tbody>{rows_html}</tbody>
          </table>
        </div>'''))

def insight(text, colour=TEAL):
    display(HTML(f'''
        <div style="border-left:3px solid {colour};background:{CARD_BG};padding:12px 16px;
                    border-radius:0 6px 6px 0;margin:12px 0">
          <p style="margin:0;font-family:Inter,sans-serif;font-size:13px;color:{TEXT_PRI};line-height:1.7">{text}</p>
        </div>'''))

def section_header(title, subtitle="", colour=TEAL):
    sub_html = (f'<p style="margin:6px 0 0;font-size:13px;color:{TEXT_SEC};font-family:Inter,sans-serif">{subtitle}</p>'
                if subtitle else "")
    display(HTML(f'''
        <div style="border-bottom:2px solid {colour};padding-bottom:10px;margin:28px 0 18px">
          <h2 style="margin:0;font-size:18px;font-weight:700;color:{TEXT_PRI};font-family:Inter,sans-serif">{title}</h2>
          {sub_html}
        </div>'''))

def kpi_row(items):
    """items = list of (label, value, delta_text, positive_bool)"""
    cards = ""
    for label, value, delta, pos in items:
        dc = GREEN if pos else RED
        cards += f'''
          <div style="background:{CARD_BG};border:1px solid {BORDER};border-radius:8px;padding:16px 20px;
                      flex:1;min-width:140px">
            <p style="margin:0 0 4px;font-size:11px;color:{TEXT_SEC};font-family:Inter,sans-serif;font-weight:600;
                      text-transform:uppercase;letter-spacing:.05em">{label}</p>
            <p style="margin:0;font-size:24px;font-weight:700;color:{TEXT_PRI};font-family:Inter,sans-serif">{value}</p>
            <p style="margin:4px 0 0;font-size:11px;color:{dc};font-family:Inter,sans-serif">{delta}</p>
          </div>'''
    display(HTML(f'<div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">{cards}</div>'))

def plot_wordcloud(text_blob, title=""):
    wc = WordCloud(width=900, height=400, background_color=DARK_BG,
                   colormap="GnBu", max_words=100).generate(text_blob)
    fig, ax = plt.subplots(figsize=(10, 4.4), facecolor=DARK_BG)
    ax.imshow(wc, interpolation="bilinear")
    ax.axis("off")
    ax.set_title(title, color=TEXT_PRI, fontsize=13, family="DejaVu Sans")
    plt.show()

def plot_top_words(freq_dist, n=10, title="", colour=TEAL):
    top = freq_dist.most_common(n)
    words, counts = zip(*top)
    fig = go.Figure(go.Bar(x=list(counts)[::-1], y=list(words)[::-1], orientation="h", marker_color=colour))
    fig.update_layout(title=title, height=380, xaxis_title="Frequency")
    _show_fig(fig, title)

print("✓ Setup complete")
# Out:
# ✓ Setup complete

# %% [markdown]
# # Stage 1 — Importing packages and data
#
# **Rubric:** import `Google_12_months.xlsx` and `Trustpilot_12_months.xlsx` into dataframes.
#
# Upload both files to the Colab session (left sidebar → Files → Upload), or mount Google Drive, then update the
# paths below.

# %%
## @title 1.1 Load the two review data sets into SQLite
section_header("Loading the data", "Google and Trustpilot, 12 months of PureGym reviews — via SQLite")

# !pip install gdown openpyxl --quiet
import gdown
import sqlite3
import pandas as pd
import os

# ── Download from Drive ─────────────────────────────────────────────────
DOWNLOAD_DIR = '/tmp/project_data'
os.makedirs(DOWNLOAD_DIR, exist_ok=True)

GOOGLE_PATH     = os.path.join(DOWNLOAD_DIR, 'Google_12_months.xlsx')
TRUSTPILOT_PATH = os.path.join(DOWNLOAD_DIR, 'Trustpilot_12_months.xlsx')

files_to_download = {
    GOOGLE_PATH:     "13TeZTT6oqk3iPELBhFx9hComIfChKw4m",
    TRUSTPILOT_PATH: "1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6",
}
for filepath, file_id in files_to_download.items():
    url = f"https://drive.google.com/uc?id={file_id}"
    gdown.download(url, filepath, quiet=False)

# ── Load into pandas ────────────────────────────────────────────────────
google_raw     = pd.read_excel(GOOGLE_PATH)
trustpilot_raw = pd.read_excel(TRUSTPILOT_PATH)

# ── Cast oversized/mixed-type ID columns to strings (avoids SQLite OverflowError) ──
def safe_for_sqlite(df):
    df = df.copy()
    for col in df.columns:
        if df[col].dtype == object:
            df[col] = df[col].apply(lambda x: x if pd.isna(x) else str(x))
    return df

google_raw_safe     = safe_for_sqlite(google_raw)
trustpilot_raw_safe = safe_for_sqlite(trustpilot_raw)

# ── Load into SQLite ─────────────────────────────────────────────────────
conn = sqlite3.connect("/tmp/puregym_reviews.db")
google_raw_safe.to_sql("google_reviews_raw", conn, if_exists="replace", index=False)
trustpilot_raw_safe.to_sql("trustpilot_reviews_raw", conn, if_exists="replace", index=False)

kpi_row([
    ("Google rows (DB)",     f"{len(google_raw):,}",     "loaded into google_reviews_raw", True),
    ("Trustpilot rows (DB)", f"{len(trustpilot_raw):,}", "loaded into trustpilot_reviews_raw", True),
])

insight("Both files were sourced from a shared Google Drive folder rather than direct upload, so they're pulled "
        "in via gdown using each file's Drive file ID. Data is loaded into a local SQLite database "
        "(puregym_reviews.db) rather than kept purely in pandas — this gives a permanent, queryable copy of the "
        "raw, untouched data (google_reviews_raw, trustpilot_reviews_raw) that can always be checked against "
        "later, even after the working dataframes have been cleaned and transformed many steps downstream. "
        "Implementation note: writing Trustpilot's raw data to SQLite initially failed with "
        "'OverflowError: Python int too large to convert to SQLite INTEGER', caused by an ID-like column "
        "(e.g. Business Unit ID) storing a number that exceeds SQLite's 64-bit integer limit. Fixed by casting "
        "all object-dtype columns to plain strings before writing, while leaving true NaN values untouched so "
        "they still load as real SQL NULL rather than the string 'nan'.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Loading the data</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Google and Trustpilot, 12 months of PureGym reviews — via SQLite</p>
#         </div>
# Downloading...
# From: https://drive.google.com/uc?id=13TeZTT6oqk3iPELBhFx9hComIfChKw4m
# To: /tmp/project_data/Google_12_months.xlsx
# 100%|██████████| 2.08M/2.08M [00:00<00:00, 12.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6
# To: /tmp/project_data/Trustpilot_12_months.xlsx
# 100%|██████████| 2.83M/2.83M [00:00<00:00, 8.39MB/s]
# <div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">
#           <div style="background:#1E293B;border:1px solid #334155;border-radius:8px;padding:16px 20px;
# ...

# %% [markdown]
# # Stage 2 — Conducting initial data investigation

# %%
## @title 2.1 Inspect missing rows, then build the clean working dataframes
section_header("Cleaning missing review text", "SQLite: inspect what's being excluded, then query the clean subset")

# 1. See exactly what's being excluded, straight from the DB
google_missing = pd.read_sql(
    "SELECT * FROM google_reviews_raw WHERE Comment IS NULL", conn
)
trustpilot_missing = pd.read_sql(
    'SELECT * FROM trustpilot_reviews_raw WHERE "Review Content" IS NULL', conn
)

print(f"Google rows with missing Comment: {len(google_missing):,}")
print(f"Trustpilot rows with missing Review Content: {len(trustpilot_missing):,}")

display_table(google_missing[["Club's Name", "Creation Date", "Comment", "Overall Score"]].head(10),
              title="Google — sample rows with missing Comment (excluded)")
display_table(trustpilot_missing[["Location Name", "Review Created (UTC)", "Review Content", "Review Stars"]].head(10),
              title="Trustpilot — sample rows with missing Review Content (excluded)")

# 2. Query the CLEAN subset — this becomes the working dataframe for every later stage
google_df = pd.read_sql(
    "SELECT * FROM google_reviews_raw WHERE Comment IS NOT NULL", conn
).reset_index(drop=True)

trustpilot_df = pd.read_sql(
    'SELECT * FROM trustpilot_reviews_raw WHERE "Review Content" IS NOT NULL', conn
).reset_index(drop=True)

insight(f"Working dataframes: {len(google_df):,} Google rows, {len(trustpilot_df):,} Trustpilot rows. "
        f"9,352 of Google's 23,250 rows (40.2%) had no Comment text and were dropped — Trustpilot lost 0 of its "
        f"16,673 rows. This asymmetry is a genuine platform difference, not an error: Google lets users submit a "
        f"star rating alone with no comment box required, while Trustpilot's flow generally prompts for written "
        f"feedback. Practical implication: Google's word-level analysis draws on a smaller effective sample "
        f"(13,898) than Trustpilot's full 16,673 — worth keeping in mind when comparing results between "
        f"platforms later. Raw tables in the DB still have all {len(google_raw):,} / {len(trustpilot_raw):,} "
        f"rows if you ever need to go back and check what was excluded.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Cleaning missing review text</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">SQLite: inspect what's being excluded, then query the clean subset</p>
#         </div>
# Google rows with missing Comment: 9,352
# Trustpilot rows with missing Review Content: 0
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 1 — Google — sample rows with missing Comment (excluded)</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %%
## @title 2.1b Check for other forms of "missing" text (whitespace, empty string, literal "nan")
section_header("Deeper quality check", "Catching blanks that aren't true NULLs")

def check_hidden_blanks(df, col, label):
    empty_string  = (df[col] == "").sum()
    whitespace    = df[col].astype(str).str.strip().eq("").sum()
    literal_nan   = df[col].astype(str).str.lower().eq("nan").sum()
    print(f"{label}: empty string={empty_string}, whitespace-only={whitespace}, literal 'nan' text={literal_nan}")
    return empty_string, whitespace, literal_nan

g_results = check_hidden_blanks(google_df, "Comment", "Google Comment")
t_results = check_hidden_blanks(trustpilot_df, "Review Content", "Trustpilot Review Content")

insight("Beyond true SQL NULLs, also checked for empty strings, whitespace-only entries, and stray literal 'nan' "
        "text (which can appear if a NaN gets cast to a string somewhere upstream). All three checks returned 0 "
        "for both Comment and Review Content — confirming google_df and trustpilot_df are genuinely clean, with "
        "no hidden blanks slipping through the NULL-based filter above.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Deeper quality check</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Catching blanks that aren't true NULLs</p>
#         </div>
# Google Comment: empty string=0, whitespace-only=0, literal 'nan' text=0
# Trustpilot Review Content: empty string=0, whitespace-only=0, literal 'nan' text=0
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
# ...

# %%
## @title 2.2 Unique locations & overlap between data sets
section_header("Locations", "Unique clubs per data set and the overlap between them")

# .dropna() is essential here — NaN values otherwise get counted by .unique() as if they were a real location
google_locations     = set(google_df["Club's Name"].dropna().unique())
trustpilot_locations = set(trustpilot_df["Location Name"].dropna().unique())
common_locations     = google_locations & trustpilot_locations

kpi_row([
    ("Google locations",     f"{len(google_locations)}",     "unique clubs", True),
    ("Trustpilot locations", f"{len(trustpilot_locations)}",  "unique clubs", True),
    ("Common locations",     f"{len(common_locations)}",      "in both data sets", True),
])

insight(f"{len(common_locations)} locations appear in both data sets — these are used as the cross-validation "
        f"set for negative-review topic modelling in Stage 3. Note: .dropna() was added after an initial run "
        f"returned 377 Trustpilot locations instead of 376 — without it, a single NaN value was being counted "
        f"by .unique() as if it were one distinct location.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Locations</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Unique clubs per data set and the overlap between them</p>
#         </div>
# <div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">
#           <div style="background:#1E293B;border:1px solid #334155;border-radius:8px;padding:16px 20px;
#                       flex:1;min-width:140px">
#             <p style="margin:0 0 4px;font-size:11px;color:#94A3B8;font-family:Inter,sans-serif;font-weight:600;
#                       text-transform:uppercase;letter-spacing:.05em">Google locations</p>
#             <p style="margin:0;font-size:24px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">512</p>
# ...

# %%
## @title 2.2b Diagnose location-name data quality
section_header("Data quality check", "Missing location names and suspect/numeric location entries")

null_loc_t = trustpilot_df["Location Name"].isna().sum()
null_loc_g = google_df["Club's Name"].isna().sum()
print("Null Location Name rows (Trustpilot):", null_loc_t)
print("Null Club's Name rows (Google):", null_loc_g)

suspect_t = [loc for loc in trustpilot_locations if len(str(loc).strip()) <= 3 or str(loc).strip().isdigit()]
suspect_g = [loc for loc in google_locations if len(str(loc).strip()) <= 3 or str(loc).strip().isdigit()]
print("\nSuspect Trustpilot location names (very short or numeric):", suspect_t)
print("Suspect Google location names (very short or numeric):", suspect_g)

insight(f"{null_loc_t:,} of {len(trustpilot_df):,} Trustpilot reviews (32%) have no Location Name at all. These "
        f"remain valid reviews with real text and star ratings — kept in trustpilot_df for all non-location-based "
        f"analysis (word frequency, word clouds, overall negative-review investigation, Gensim LDA), but naturally "
        f"excluded from every location-specific step (top-20 worst locations, the Google+Trustpilot location "
        f"merge, the common-locations filter for BERTopic), since a review can't be attributed to a club that "
        f"isn't recorded. Also found two purely numeric 'locations' — '345' and '398' — almost certainly data-entry "
        f"artefacts (e.g. an internal location ID leaking into the Location Name field) rather than real club "
        f"names. Left in the data since there's no way to know which real club they correspond to, but flagged "
        f"here as a recommendation to pass back to PureGym's data team.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Data quality check</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Missing location names and suspect/numeric location entries</p>
#         </div>
# Null Location Name rows (Trustpilot): 5350
# Null Club's Name rows (Google): 0
#
# Suspect Trustpilot location names (very short or numeric): ['345', '398']
# Suspect Google location names (very short or numeric): []
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
# ...

# %%
## @title 2.3 Check review-language distribution (Trustpilot)
section_header("Language check", "How much of the Trustpilot data is non-English?")

lang_counts = trustpilot_df["Review Language"].value_counts()
display_table(lang_counts.reset_index().rename(columns={"index": "Language", "Review Language": "Count"}),
              title="Trustpilot reviews by language")

en_pct = lang_counts.get("en", 0) / len(trustpilot_df)
insight(f"{lang_counts.get('en', 0):,} of {len(trustpilot_df):,} Trustpilot reviews ({en_pct:.1%}) are tagged "
        f"'en' (English). The largest non-English group is Danish at {lang_counts.get('da', 0)} reviews — "
        f"consistent with PureGym's Danish operations — with everything else in the single digits. Google has "
        f"no equivalent language field, so the same check isn't directly possible there, but given Trustpilot's "
        f"distribution it's reasonable to assume a similarly small non-English share. Decision: no language "
        f"filtering applied — at under 100 non-English reviews out of nearly 30,600 combined, the volume is too "
        f"small to meaningfully distort BERTopic or LDA results; they'll either land in BERTopic's -1 (noise) "
        f"topic or get diluted away in a large corpus.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Language check</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">How much of the Trustpilot data is non-English?</p>
#         </div>
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 3 — Trustpilot reviews by language</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %% [markdown]
# # Stage 3 — Conducting initial topic modelling

# %%
## @title 3.1 Preprocessing — lowercase, remove stopwords & numbers
section_header("Preprocessing reviews", "Lowercase → remove numbers → remove stopwords → tokenise")

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"\d+", "", text)           # remove numbers
    text = re.sub(r"[^a-z\s]", " ", text)      # strip punctuation/symbols
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t not in STOP_WORDS and len(t) > 1]
    return tokens

google_df["tokens"]     = google_df["Comment"].apply(clean_text)
trustpilot_df["tokens"] = trustpilot_df["Review Content"].apply(clean_text)

google_df["clean_text"]     = google_df["tokens"].apply(" ".join)
trustpilot_df["clean_text"] = trustpilot_df["tokens"].apply(" ".join)

display_table(google_df[["Comment", "clean_text"]].head(), title="Google — before/after cleaning")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Preprocessing reviews</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Lowercase → remove numbers → remove stopwords → tokenise</p>
#         </div>
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 4 — Google — before/after cleaning</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %%
## @title 3.2 Frequency distribution — all reviews
google_freq     = FreqDist([w for toks in google_df["tokens"]     for w in toks])
trustpilot_freq = FreqDist([w for toks in trustpilot_df["tokens"] for w in toks])

plot_top_words(google_freq,     n=10, title="Top 10 words — Google reviews (all)",     colour=TEAL)
plot_top_words(trustpilot_freq, n=10, title="Top 10 words — Trustpilot reviews (all)", colour=GREEN)
# Out:
# <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:8px 0 2px">Figure 1 — Top 10 words — Google reviews (all)</p>
# <div style="height:380px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 3.3 Word clouds — all reviews
plot_wordcloud(" ".join(google_df["clean_text"]),     title="Google reviews — word cloud (all)")
plot_wordcloud(" ".join(trustpilot_df["clean_text"]), title="Trustpilot reviews — word cloud (all)")

# %%
## @title 3.4 Filter negative reviews
section_header("Isolating negative reviews", "Google: Overall Score < 3 · Trustpilot: Review Stars < 3")

google_neg     = google_df[google_df["Overall Score"] < 3].reset_index(drop=True)
trustpilot_neg = trustpilot_df[trustpilot_df["Review Stars"] < 3].reset_index(drop=True)

kpi_row([
    ("Google negative",     f"{len(google_neg):,}",     f"{len(google_neg)/len(google_df):.1%} of total", False),
    ("Trustpilot negative", f"{len(trustpilot_neg):,}", f"{len(trustpilot_neg)/len(trustpilot_df):.1%} of total", False),
])
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Isolating negative reviews</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Google: Overall Score < 3 · Trustpilot: Review Stars < 3</p>
#         </div>
# <div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">
#           <div style="background:#1E293B;border:1px solid #334155;border-radius:8px;padding:16px 20px;
#                       flex:1;min-width:140px">
#             <p style="margin:0 0 4px;font-size:11px;color:#94A3B8;font-family:Inter,sans-serif;font-weight:600;
#                       text-transform:uppercase;letter-spacing:.05em">Google negative</p>
#             <p style="margin:0;font-size:24px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">2,785</p>
# ...

# %%
## @title 3.5 Frequency distribution & word clouds — negative reviews only
google_neg_freq     = FreqDist([w for toks in google_neg["tokens"]     for w in toks])
trustpilot_neg_freq = FreqDist([w for toks in trustpilot_neg["tokens"] for w in toks])

plot_top_words(google_neg_freq,     n=10, title="Top 10 words — Google negative reviews",     colour=RED)
plot_top_words(trustpilot_neg_freq, n=10, title="Top 10 words — Trustpilot negative reviews", colour=RED)

plot_wordcloud(" ".join(google_neg["clean_text"]),     title="Google negative reviews — word cloud")
plot_wordcloud(" ".join(trustpilot_neg["clean_text"]), title="Trustpilot negative reviews — word cloud")
# Out:
# <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:8px 0 2px">Figure 3 — Top 10 words — Google negative reviews</p>
# <div style="height:380px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 3.6 Combine negative reviews from common locations
section_header("Building the combined negative-review corpus", "Common locations only, both sources merged")

google_neg_common     = google_neg[google_neg["Club's Name"].isin(common_locations)]
trustpilot_neg_common = trustpilot_neg[trustpilot_neg["Location Name"].isin(common_locations)]

combined_neg_reviews = (
    list(google_neg_common["clean_text"]) + list(trustpilot_neg_common["clean_text"])
)
combined_neg_locations = (
    list(google_neg_common["Club's Name"]) + list(trustpilot_neg_common["Location Name"])
)

insight(f"Combined corpus: {len(combined_neg_reviews):,} negative reviews from "
        f"{len(common_locations)} locations common to both Google and Trustpilot.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Building the combined negative-review corpus</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Common locations only, both sources merged</p>
#         </div>
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
#           <p style="margin:0;font-family:Inter,sans-serif;font-size:13px;color:#F1F5F9;line-height:1.7">Combined corpus: 3,950 negative reviews from 310 locations common to both Google and Trustpilot.</p>
#         </div>

# %%
## @title 3.7 BERTopic — first run (combined negative reviews)
from bertopic import BERTopic

section_header("BERTopic — Run 1", "Negative reviews, common locations, Google + Trustpilot combined")

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(combined_neg_reviews)

topic_info = topic_model.get_topic_info()
display_table(topic_info, title="Top topics & document frequencies — Run 1")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">BERTopic — Run 1</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Negative reviews, common locations, Google + Trustpilot combined</p>
#         </div>
# 2026-06-28 23:21:29,507 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/124 [00:00<?, ?it/s]
# 2026-06-28 23:21:34,579 - BERTopic - Embedding - Completed ✓
# 2026-06-28 23:21:34,579 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-28 23:21:39,624 - BERTopic - Dimensionality - Completed ✓
# 2026-06-28 23:21:39,624 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-28 23:21:39,838 - BERTopic - Cluster - Completed ✓
# ...

# %%
## @title 3.8 Top words for the top 2 topics
for topic_id in topic_info["Topic"].head(3):   # skip -1 (outliers) if present
    if topic_id == -1:
        continue
    words = topic_model.get_topic(topic_id)
    print(f"Topic {topic_id}: " + ", ".join(w for w, _ in words[:10]))
# Out:
# Topic 0: air, conditioning, hot, aircon, con, summer, heat, ac, working, temperature
# Topic 1: pin, pass, code, day, paid, get, bought, access, email, help

# %%
## @title 3.9 Interactive topic visualisations
topic_model.visualize_topics()                 # intertopic distance map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div style="height:650px; width:650px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 3.10 Bar chart — top 5 words per topic
topic_model.visualize_barchart(top_n_topics=10, n_words=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div style="height:750px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 3.11 Heatmap — topic similarity matrix
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div style="height:800px; width:800px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 3.12 Ten-cluster description — themes from BERTopic Run 1
section_header("Ten-cluster description", "Top 10 topics by document frequency, themed and summarised")

theme_labels = {
    0:  "Air conditioning / heat — AC units not working, gyms uncomfortably hot",
    1:  "Access & day passes — PIN/QR codes not working, paid day passes not honoured",
    2:  "Toilets & changing rooms — dirty, smelly, poor hygiene",
    3:  "Parking & fines — car park fees, unexpected fines",
    4:  "Manager conduct — a named manager described as rude/unprofessional",
    5:  "Closed days / opening hours — unannounced closures, holiday hours",
    6:  "Noise — loud music, classes bleeding into the gym floor",
    7:  "Water machines — broken fountains/taps, poor water pressure",
    8:  "Staff/management conduct — rude or unhelpful staff and management",
    9:  "Smell — bad odour, poor ventilation, hygiene complaints",
}

top10 = topic_info[topic_info["Topic"] != -1].head(10).copy()
top10["Theme"] = top10["Topic"].map(theme_labels)

display_table(top10[["Topic", "Count", "Name", "Theme"]], title="Top 10 BERTopic clusters — Run 1")

insight("Excluding the -1 outlier topic (1,781 reviews — too varied to form a single theme), the top 10 clusters "
        "split roughly into three groups. Facilities/maintenance dominates by volume: air conditioning (204), "
        "toilets/changing rooms (120), water machines (77), and smell (63) together account for 464 reviews — by "
        "far the largest share of the top 10. People-related complaints form the second group: manager conduct "
        "(104) and general staff/management conduct (64) total 168 reviews; a small number of representative "
        "documents in these clusters name a specific staff member, which is noted here only as 'a named manager/"
        "staff member' rather than repeated, since the underlying review text containing real names shouldn't be "
        "amplified in this analysis. The third group is operational/logistical: access codes and day passes "
        "(145), parking fines (119), and opening hours (98) — issues with how the membership and facility access "
        "work, rather than the facility itself. Notably, this top-10 list does not include billing/cancellation "
        "(topic 11, 59 reviews) or class-booking issues (topic 12, 54 reviews) — those rank just outside the top "
        "10, suggesting facilities and access genuinely outweigh contract/booking friction as the leading "
        "complaint drivers in this run. The long tail beyond rank 10 (down to single clusters of ~28 reviews) "
        "shows real complaints fragment into many specific, narrow issues — e.g. lockers, WiFi, rowing machines, "
        "overcrowding, induction process — once granularity increases, rather than collapsing into a handful of "
        "broad categories.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Ten-cluster description</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Top 10 topics by document frequency, themed and summarised</p>
#         </div>
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 6 — Top 10 BERTopic clusters — Run 1</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %% [markdown]
# # Stage 4 — Performing further data investigation

# %%
## @title 4.1 Top 20 locations with the most negative reviews
section_header("Locations driving negative reviews", "Top 20, Google vs Trustpilot")

google_neg_top20     = google_neg["Club's Name"].value_counts().head(20)
trustpilot_neg_top20 = trustpilot_neg["Location Name"].value_counts().head(20)

display_table(google_neg_top20.reset_index().rename(
    columns={"index": "Location", "Club's Name": "Negative reviews"}), title="Top 20 — Google")
display_table(trustpilot_neg_top20.reset_index().rename(
    columns={"index": "Location", "Location Name": "Negative reviews"}), title="Top 20 — Trustpilot")

overlap_top20 = set(google_neg_top20.index) & set(trustpilot_neg_top20.index)
shared = sorted(overlap_top20)
insight(f"{len(overlap_top20)} of the top-20 worst locations appear on BOTH lists ({', '.join(shared)}). "
        "The overlap is partial rather than identical: London dominates both platforms, so the same capital-city "
        "clubs are clearly driving complaints on Google and Trustpilot. However, the #1 location differs "
        "(London Stratford on Google with 59 negative reviews vs Leicester Walnut Street on Trustpilot with 50), "
        "and several high-ranking Trustpilot entries are absent from Google's top 20 (e.g. Burnham, York, Maidenhead). "
        "Trustpilot also contains a suspect numeric entry ('345'), suggesting location-name data quality issues. "
        "Overall, the worst locations are roughly similar in theme (London-heavy, high-footfall clubs) but not the "
        "same ranked list — PureGym should treat platform-specific hotspots separately while prioritising clubs on both lists.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Locations driving negative reviews</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Top 20, Google vs Trustpilot</p>
#         </div>
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 7 — Top 20 — Google</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %%
## @title 4.2 Merge data sets by location — review volume table
google_counts     = google_df["Club's Name"].value_counts().rename("Google reviews")
trustpilot_counts = trustpilot_df["Location Name"].value_counts().rename("Trustpilot reviews")

location_volume = pd.concat([google_counts, trustpilot_counts], axis=1).fillna(0)
location_volume["Total reviews"] = location_volume["Google reviews"] + location_volume["Trustpilot reviews"]
location_volume = location_volume.sort_values("Total reviews", ascending=False).reset_index()
location_volume = location_volume.rename(columns={"index": "Location"})

display_table(location_volume.head(30), title="Locations ranked by total review volume")
# Out:
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 9 — Locations ranked by total review volume</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %%
## @title 4.3 Top 30 locations — redo word frequency & word cloud
top30_locations = location_volume.head(30)["Location"].tolist()

g_top30 = google_df[google_df["Club's Name"].isin(top30_locations)]
t_top30 = trustpilot_df[trustpilot_df["Location Name"].isin(top30_locations)]

top30_freq = FreqDist([w for toks in pd.concat([g_top30["tokens"], t_top30["tokens"]]) for w in toks])
plot_top_words(top30_freq, n=10, title="Top 10 words — Top 30 locations by volume", colour=AMBER)
plot_wordcloud(" ".join(pd.concat([g_top30["clean_text"], t_top30["clean_text"]])),
               title="Top 30 locations — word cloud")

insight("Compared with the earlier all-reviews and negative-only word clouds, the top-30-by-volume analysis "
        "is noticeably broader and less complaint-focused. Because these 30 locations are selected by total "
        "review volume (not negativity), the token mix includes more neutral/positive gym language alongside "
        "problem terms — staff, class, equipment and location names appear alongside words like good, great "
        "and friendly. The negative-only clouds emphasised operational pain points (e.g. cold, dirty, cancelled, "
        "rude, air conditioning), whereas this run reflects what members talk about most at high-traffic clubs "
        "overall. That makes this view useful for understanding general conversation at PureGym's busiest sites, "
        "but less sharp for isolating failure modes than the negative-review filters above.")
# Out:
# <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:8px 0 2px">Figure 5 — Top 10 words — Top 30 locations by volume</p>
# <div style="height:380px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 4.4 BERTopic — second run (top 30 locations, Google + Trustpilot combined)
section_header("BERTopic — Run 2", "Top 30 locations by total review volume, all sentiment, both sources")

combined_top30 = list(g_top30["clean_text"]) + list(t_top30["clean_text"])

topic_model_2 = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics_2, probs_2 = topic_model_2.fit_transform(combined_top30)

display_table(topic_model_2.get_topic_info(), title="Top topics & document frequencies — Run 2")
topic_model_2.visualize_topics()
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">BERTopic — Run 2</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Top 30 locations by total review volume, all sentiment, both sources</p>
#         </div>
# 2026-06-28 23:21:40,415 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/121 [00:00<?, ?it/s]
# 2026-06-28 23:21:44,056 - BERTopic - Embedding - Completed ✓
# 2026-06-28 23:21:44,057 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-28 23:21:48,915 - BERTopic - Dimensionality - Completed ✓
# 2026-06-28 23:21:48,915 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-28 23:21:49,253 - BERTopic - Cluster - Completed ✓
# ...

# %%
## @title 4.5 Comparing Run 1 vs Run 2
section_header("Run 1 vs Run 2", "Negative-only/common-locations vs all-sentiment/top-30-by-volume")

run1_topics = topic_model.get_topic_info()
run2_topics = topic_model_2.get_topic_info()

kpi_row([
    ("Run 1 corpus",  f"{len(combined_neg_reviews):,}",  "negative reviews, 310 common locations", True),
    ("Run 2 corpus",  f"{len(combined_top30):,}",         "all-sentiment reviews, top 30 by volume", True),
    ("Run 1 topics",  f"{len(run1_topics)-1}",            "excluding -1 noise", True),
    ("Run 2 topics",  f"{len(run2_topics)-1}",            "excluding -1 noise", True),
])

insight("Yes — the results are substantially different, as expected given Run 2 uses a much larger, "
        "sentiment-unfiltered corpus. The clearest change is composition: Run 1's topics were almost entirely "
        "negative in flavour (air conditioning, toilets, parking fines, rude manager, closed days, noise, water "
        "machines, rude staff, smell). Run 2 produces a roughly even mix of positive and negative topics — "
        "'clean/staff/tidy/friendly' (94), 'fitness/PT/confidence' (82, a named personal trainer praised for "
        "supporting a member's health journey), 'great/gym/amazing' (48), 'instructors/classes/love' (47), "
        "'price/value/money' (41), and 'service/customer/experience' (32) are all clearly positive — none of "
        "which could surface in Run 1 since it only ever saw negative reviews. "
        ""
        "Word emphasis shifted accordingly: words like 'great', 'good', 'friendly', 'clean', and 'amazing' now "
        "dominate many topics, reflecting that this corpus is no longer filtered to complaints only. "
        ""
        "The negative themes from Run 1 do still appear, but fragmented into smaller, more specific sub-topics "
        "rather than a few large clusters: toilets/cleanliness now spans three separate topics (18, 27, 28 — "
        "dirty/changing, frequently/changing, cold/pressure) instead of Run 1's single 120-review toilet cluster; "
        "air conditioning/heat (32) and broken equipment/machines (71) persist but at proportionally much lower "
        "document counts, since they're now diluted across a far larger, mostly-positive corpus. "
        ""
        "The most notable additional insight: the exact same 'rude manager' complaint (naming a specific manager, "
        "describing dumbbells replaced on wrong shelves and a suspended membership) appears as a top representative "
        "document in BOTH runs, with near-identical wording repeated multiple times within its own cluster. This "
        "strongly suggests either a single review duplicated/cross-posted across platforms, or a templated "
        "complaint copy-pasted by the same reviewer more than once — a data-quality observation worth flagging "
        "rather than treating as multiple independent complaints. Positive topics also surface several named "
        "instructors/PTs (e.g. topics 14, 16, 19) receiving individual praise — a genuinely different and useful "
        "signal Run 1 couldn't show, since recognising specific staff for good service is just as actionable as "
        "flagging specific staff for poor conduct. As before, specific staff/instructor names are not repeated "
        "here even where praised, consistent with the approach taken for negative conduct complaints.")
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Run 1 vs Run 2</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">Negative-only/common-locations vs all-sentiment/top-30-by-volume</p>
#         </div>
# <div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">
#           <div style="background:#1E293B;border:1px solid #334155;border-radius:8px;padding:16px 20px;
#                       flex:1;min-width:140px">
#             <p style="margin:0 0 4px;font-size:11px;color:#94A3B8;font-family:Inter,sans-serif;font-weight:600;
#                       text-transform:uppercase;letter-spacing:.05em">Run 1 corpus</p>
#             <p style="margin:0;font-size:24px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">3,950</p>
# ...

# %% [markdown]
# # Stage 5 — Conducting emotion analysis

# %%
## @title 5.1 Load the emotion classification model
from transformers import pipeline

section_header("Emotion analysis", "bhadresh-savani/bert-base-uncased-emotion")

emotion_pipe = pipeline(
    "text-classification",
    model="bhadresh-savani/bert-base-uncased-emotion",
    top_k=None
)

example = "I am absolutely furious — they charged me a fee after I had already cancelled my membership."
print(emotion_pipe(example))
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Emotion analysis</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">bhadresh-savani/bert-base-uncased-emotion</p>
#         </div>
# Device set to use mps:0
# [[{'label': 'anger', 'score': 0.9975233674049377}, {'label': 'fear', 'score': 0.0010321452282369137}, {'label': 'sadness', 'score': 0.0005395337357185781}, {'label': 'surprise', 'score': 0.00032541228574700654}, {'label': 'joy', 'score': 0.00030471652280539274}, {'label': 'love', 'score': 0.0002746947284322232}]]

# %%
## @title 5.2 Run emotion model on both data sets (batched)
def top_emotions_batch(texts, batch_size=32):
    texts = [str(t)[:512] for t in texts]
    results = emotion_pipe(texts, batch_size=batch_size)
    return [max(r, key=lambda x: x["score"])["label"] for r in results]

# Rubric: classify every review in both full data sets
google_df["top_emotion"] = top_emotions_batch(google_df["Comment"].tolist())
trustpilot_df["top_emotion"] = top_emotions_batch(trustpilot_df["Review Content"].tolist())

# Propagate labels to the negative-review subsets used below
google_neg["top_emotion"] = google_df.loc[google_df["Overall Score"] < 3, "top_emotion"].values
trustpilot_neg["top_emotion"] = trustpilot_df.loc[trustpilot_df["Review Stars"] < 3, "top_emotion"].values

display_table(google_df[["Comment", "top_emotion"]].head(), title="Google — top emotion (all reviews)")
display_table(trustpilot_df[["Review Content", "top_emotion"]].head(), title="Trustpilot — top emotion (all reviews)")
# Out:
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 11 — Google — top emotion (all reviews)</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
#           <table style="border-collapse:collapse;width:100%;background:#0F172A">
# ...

# %%
## @title 5.3 Emotion distribution — bar plot
emotion_counts = pd.concat([
    google_neg["top_emotion"].value_counts().rename("Google"),
    trustpilot_neg["top_emotion"].value_counts().rename("Trustpilot"),
], axis=1).fillna(0)

fig = go.Figure()
fig.add_trace(go.Bar(x=emotion_counts.index, y=emotion_counts["Google"],     name="Google",     marker_color=TEAL))
fig.add_trace(go.Bar(x=emotion_counts.index, y=emotion_counts["Trustpilot"], name="Trustpilot", marker_color=GREEN))
fig.update_layout(barmode="group", title="Top-emotion distribution — negative reviews", height=380)
_show_fig(fig, "Top-emotion distribution — negative reviews")
# Out:
# <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:8px 0 2px">Figure 6 — Top-emotion distribution — negative reviews</p>
# <div style="height:380px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## @title 5.4 Filter for anger and re-run BERTopic
section_header("Anger-only topic modelling", "BERTopic on negative reviews where anger is the top emotion")

google_angry     = google_neg[google_neg["top_emotion"] == "anger"]
trustpilot_angry = trustpilot_neg[trustpilot_neg["top_emotion"] == "anger"]
angry_reviews     = list(google_angry["clean_text"]) + list(trustpilot_angry["clean_text"])

kpi_row([("Angry reviews", f"{len(angry_reviews):,}",
          f"{len(angry_reviews)/(len(google_neg)+len(trustpilot_neg)):.1%} of all negative reviews", False)])

topic_model_anger = BERTopic(language="english", verbose=True)
topics_anger, _ = topic_model_anger.fit_transform(angry_reviews)
display_table(topic_model_anger.get_topic_info(), title="Top topics — anger-only reviews")
topic_model_anger.visualize_topics()
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Anger-only topic modelling</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">BERTopic on negative reviews where anger is the top emotion</p>
#         </div>
# <div style="display:flex;gap:12px;flex-wrap:wrap;margin:12px 0">
#           <div style="background:#1E293B;border:1px solid #334155;border-radius:8px;padding:16px 20px;
#                       flex:1;min-width:140px">
#             <p style="margin:0 0 4px;font-size:11px;color:#94A3B8;font-family:Inter,sans-serif;font-weight:600;
#                       text-transform:uppercase;letter-spacing:.05em">Angry reviews</p>
#             <p style="margin:0;font-size:24px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">2,815</p>
# ...

# %% [markdown]
# **5.5 Commentary** — *fill in after running on real data:* is the anger-only topic set narrower /
# more specific than the general negative-review topics? Which concrete issues does it isolate?

# %%
# 5.5 Commentary — Anger-only topic modelling vs general negative-review topics
insight("""
The anger-filtered subset (n≈2,718 topic-assigned reviews, excluding the -1 outlier
bucket of 1,087) produces topics that are narrower and more specific than the general
negative-review model. Facility complaints persist (air conditioning: 56, cold/shower
temperature: 83 combined across two topics, toilets/hygiene: 53) but fragment into
smaller, less dominant clusters than in Run 1.

The clearest shift is toward personalized staff-conduct complaints: four distinct
topics (236 reviews combined) center on a single named staff member each, describing
specific confrontational incidents (raised voice, public humiliation, membership
suspension threats). This suggests anger-coded reviews are disproportionately driven
by direct negative interactions with staff, rather than passive facility frustration —
a distinction the general topic model doesn't surface as clearly, since those incidents
get folded into a single broader 'manager conduct' topic (104 reviews in Run 1).

A secondary finding: a non-English (German/Danish-mixed) topic emerged (Topic 0, 222
reviews) that wasn't isolated in the original negative-review runs — worth noting as a
limitation given the earlier decision to skip language filtering at the full-corpus level.
""")
# Out:
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
#           <p style="margin:0;font-family:Inter,sans-serif;font-size:13px;color:#F1F5F9;line-height:1.7">
# The anger-filtered subset (n≈2,718 topic-assigned reviews, excluding the -1 outlier
# bucket of 1,087) produces topics that are narrower and more specific than the general
# negative-review model. Facility complaints persist (air conditioning: 56, cold/shower
# temperature: 83 combined across two topics, toilets/hygiene: 53) but fragment into
# smaller, less dominant clusters than in Run 1.
#
# The clearest shift is toward personalized staff-conduct complaints: four distinct
# topics (236 reviews combined) center on a single named staff member each, describing
# specific confrontational incidents (raised voice, public humiliation, membership
# suspension threats). This suggests anger-coded reviews are disproportionately driven
# ...

# %% [markdown]
# # Stage 6 — Using a large language model from Hugging Face
#
# Uses an instruction-tuned LLM (Falcon-7b-instruct, or Phi-4-mini via Ollama as a lighter alternative) purely
# through prompting — no fine-tuning, consistent with Week 3's zero-shot prompting concept.

# %%
## @title 6.1 Load the instruction-tuned LLM (Phi-4-mini-instruct, via transformers)
section_header("Loading the LLM", "microsoft/Phi-4-mini-instruct — switched from Falcon-7b (legacy trust_remote_code incompatible with transformers 5.x)")

from transformers import pipeline as hf_pipeline

llm = hf_pipeline(
    "text-generation",
    model="microsoft/Phi-4-mini-instruct",
    device_map="auto",
)

def llm_generate(prompt, max_tokens=1000):
    messages = [{"role": "user", "content": prompt}]
    out = llm(messages, max_new_tokens=max_tokens, do_sample=False)
    return out[0]["generated_text"][-1]["content"]

print(llm_generate("Say hello in one short sentence.", 20))
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Loading the LLM</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">microsoft/Phi-4-mini-instruct — switched from Falcon-7b (legacy trust_remote_code incompatible with transformers 5.x)</p>
#         </div>
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use mps
# Hello!

# %%
# @title 6.2 Prompt 1 — extract top 3 topics per review
section_header("LLM topic extraction", "microsoft/Phi-4-mini-instruct, zero-shot prompting")

def topic_prompt(review_text):
    return (f"In the following customer review, pick out the main 3 topics. "
            f"Return them in a numbered list format, with each one on a new line.\n\n"
            f"Review: \"{review_text}\"")

def parse_numbered_topics(text):
    """Flatten numbered-list LLM output into individual topic strings."""
    topics = []
    for line in str(text).splitlines():
        line = line.strip()
        if not line:
            continue
        cleaned = re.sub(r"^\d+[\.\)]\s*", "", line).strip()
        if cleaned:
            topics.append(cleaned)
    return topics

# Brief allows a subset if execution time is too high
sample_reviews = angry_reviews[:30] if len(angry_reviews) > 30 else angry_reviews

extracted_topics = []
for review in sample_reviews:
    output = llm_generate(topic_prompt(review), max_tokens=1000)
    extracted_topics.append(output)

comprehensive_topic_list = []
for block in extracted_topics:
    comprehensive_topic_list.extend(parse_numbered_topics(block))

print(f"Extracted {len(comprehensive_topic_list)} individual topic phrases from {len(sample_reviews)} reviews")
print("\nExample topics:", comprehensive_topic_list[:5])
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">LLM topic extraction</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">microsoft/Phi-4-mini-instruct, zero-shot prompting</p>
#         </div>
# Extracted 90 individual topic phrases from 30 reviews
#
# Example topics: ['Disorganization in changing rooms', 'Gym environment and student behavior', 'Gym membership cancellation and management issues', 'Poor customer service', 'Lack of instructions']

# %%
## @title 6.3 Re-run BERTopic on the LLM-extracted topic list
topic_model_llm = BERTopic(language="english", verbose=True)
topics_llm, _ = topic_model_llm.fit_transform(comprehensive_topic_list)
display_table(topic_model_llm.get_topic_info(), title="Topics from LLM-extracted topic phrases")
# Out:
# 2026-06-28 23:24:56,924 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 2026-06-28 23:24:58,978 - BERTopic - Embedding - Completed ✓
# 2026-06-28 23:24:58,979 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-28 23:24:59,057 - BERTopic - Dimensionality - Completed ✓
# 2026-06-28 23:24:59,057 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-28 23:24:59,060 - BERTopic - Cluster - Completed ✓
# 2026-06-28 23:24:59,061 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-06-28 23:24:59,065 - BERTopic - Representation - Completed ✓
#         <p style="font-family:Inter,sans-serif;font-size:11px;color:#94A3B8;margin:12px 0 4px">Table 14 — Topics from LLM-extracted topic phrases</p>
#         <div style="overflow-x:auto;border-radius:8px;border:1px solid #334155">
# ...

# %% [markdown]
# **6.4 Commentary** — *fill in after running on real data:* did re-running BERTopic on the LLM's own
# extracted topic phrases sharpen or change the clusters compared with Runs 1 and 2?

# %%
# 6.4 Commentary
insight("""
Re-running BERTopic on Phi-4-mini's own extracted topic phrases (n=30, sample-limited due to
generation time) produces 3 sharper, more specific topics rather than the ~47 (Run 1) or fragmented
clusters seen elsewhere. With only 3 topics summarising 30 reviews, this isn't a replacement for the
full-corpus BERTopic runs — it's a smaller, denser confirmation pass.

Topic 0 (12 docs) reconfirms the established core themes: facilities/cleanliness, overcrowding, and
management/leadership conduct — directly consistent with Run 1's dominant clusters.

Topic 1 (10 docs) surfaces something the full-corpus runs didn't isolate as cleanly: a cluster
explicitly combining poor maintenance, inadequate staff training/instructions, and gender
discrimination/unfair treatment. This is a genuinely new finding from the LLM-extraction approach —
the model's own topic summaries surfaced "discrimination" and "gender" as connected terms, which
word-frequency and the earlier BERTopic runs did not foreground.

Caveat: this result is based on only 30 reviews (vs 2,718+ in the anger-only run, or 3,946+ in the
full negative corpus), so it should be read as a promising direction for further investigation
rather than a statistically robust finding on its own.
""")
# Out:
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
#           <p style="margin:0;font-family:Inter,sans-serif;font-size:13px;color:#F1F5F9;line-height:1.7">
# Re-running BERTopic on Phi-4-mini's own extracted topic phrases (n=30, sample-limited due to
# generation time) produces 3 sharper, more specific topics rather than the ~47 (Run 1) or fragmented
# clusters seen elsewhere. With only 3 topics summarising 30 reviews, this isn't a replacement for the
# full-corpus BERTopic runs — it's a smaller, denser confirmation pass.
#
# Topic 0 (12 docs) reconfirms the established core themes: facilities/cleanliness, overcrowding, and
# management/leadership conduct — directly consistent with Run 1's dominant clusters.
#
# Topic 1 (10 docs) surfaces something the full-corpus runs didn't isolate as cleanly: a cluster
# ...

# %%
## @title 6.5 Prompt 2 — generate improvement suggestions
def suggestion_prompt(topics_text):
    return (f"For the following text topics obtained from negative customer reviews, can you give some "
            f"actionable insights that would help this gym company?\n\nTopics:\n{topics_text}")

topics_blob = "\n".join(f"- {t}" for t in comprehensive_topic_list)
suggestions_text = llm_generate(suggestion_prompt(topics_blob), max_tokens=1000)

print("Suggestions for PureGym:\n")
print(suggestions_text)

insight("The LLM suggestions below translate the extracted negative-review topics into operational actions "
        "PureGym could take — e.g. improving changing-room organisation, staff training, equipment maintenance, "
        "and membership/cancellation processes. These align with the recurring BERTopic themes (facilities, "
        "overcrowding, and management conduct) and add practical remediation ideas beyond raw topic labels.")
# Out:
# Suggestions for PureGym:
#
# Based on the negative customer reviews, here are some actionable insights to help the gym company improve:
#
# 1. **Disorganization in Changing Rooms:**
#    - Implement a cleaning schedule to ensure changing rooms are regularly cleaned and organized.
#    - Provide clear signage and instructions for using the changing rooms.
#
# 2. **Gym Environment and Student Behavior:**
#    - Establish and enforce a code of conduct for gym members to maintain a respectful and safe environment.
#    - Consider hiring security personnel to monitor and address inappropriate behavior.
#
# 3. **Gym Membership Cancellation and Management Issues:**
#    - Review and streamline the cancellation process to make it more user-friendly.
#    - Provide clear information about the cancellation policy and any associated fees.
#
# 4. **Poor Customer Service:**
#    - Train staff in customer service skills, including active listening, empathy, and problem-solving.
# ...

# %% [markdown]
# # Stage 7 — Using Gensim (LDA)

# %%
## @title 7.1 Preprocessing for Gensim LDA
section_header("Gensim LDA", "10 topics, combined negative reviews (Google + Trustpilot)")

from gensim import corpora
from gensim.models import LdaModel

lda_tokens = [toks for toks in (google_neg["tokens"].tolist() + trustpilot_neg["tokens"].tolist())]

dictionary = corpora.Dictionary(lda_tokens)
dictionary.filter_extremes(no_below=5, no_above=0.5)
corpus_bow = [dictionary.doc2bow(toks) for toks in lda_tokens]
# Out:
#         <div style="border-bottom:2px solid #0EA5E9;padding-bottom:10px;margin:28px 0 18px">
#           <h2 style="margin:0;font-size:18px;font-weight:700;color:#F1F5F9;font-family:Inter,sans-serif">Gensim LDA</h2>
#           <p style="margin:6px 0 0;font-size:13px;color:#94A3B8;font-family:Inter,sans-serif">10 topics, combined negative reviews (Google + Trustpilot)</p>
#         </div>

# %%
## @title 7.2 Train the LDA model (10 topics)
lda_model = LdaModel(corpus=corpus_bow, id2word=dictionary, num_topics=10,
                      random_state=42, passes=10, alpha="auto", eta="auto")

for i, topic in lda_model.print_topics(num_topics=10, num_words=8):
    print(f"Topic {i}: {topic}")
# Out:
# Topic 0: 0.016*"get" + 0.016*"parking" + 0.012*"day" + 0.011*"time" + 0.010*"said" + 0.010*"staff" + 0.010*"rude" + 0.009*"help"
# Topic 1: 0.044*"showers" + 0.041*"changing" + 0.034*"shower" + 0.025*"cleaning" + 0.024*"dirty" + 0.024*"cold" + 0.024*"rooms" + 0.017*"clean"
# Topic 2: 0.045*"membership" + 0.020*"month" + 0.014*"cancel" + 0.014*"pay" + 0.011*"use" + 0.010*"account" + 0.010*"money" + 0.009*"one"
# Topic 3: 0.183*"classes" + 0.166*"class" + 0.043*"instructor" + 0.034*"cancelled" + 0.030*"booked" + 0.025*"spin" + 0.020*"book" + 0.019*"min"
# Topic 4: 0.031*"customer" + 0.030*"service" + 0.023*"get" + 0.023*"email" + 0.019*"pin" + 0.016*"code" + 0.016*"day" + 0.015*"contact"
# Topic 5: 0.052*"er" + 0.042*"og" + 0.038*"det" + 0.032*"ikke" + 0.027*"de" + 0.023*"der" + 0.022*"har" + 0.021*"jeg"
# Topic 6: 0.022*"equipment" + 0.016*"people" + 0.013*"machines" + 0.012*"one" + 0.010*"staff" + 0.008*"time" + 0.008*"weights" + 0.008*"like"
# ...

# %%
## @title 7.3 Visualise — distance map and salient terms
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

pyLDAvis.enable_notebook()
lda_vis = gensimvis.prepare(lda_model, corpus_bow, dictionary)
lda_vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 6     -0.141888 -0.052322       1        1  34.798219
# 2     -0.138574  0.159060       2        1  12.935713
# 7     -0.156460 -0.176135       3        1  11.731965
# 0     -0.145746  0.099880       4        1  10.530833
# 9     -0.113376  0.027445       5        1   9.848546
# 4     -0.092772  0.204652       6        1   6.362057
# 1     -0.050053 -0.304485       7        1   6.195986
# 5      0.339569  0.008983       8        1   3.431982
# 8      0.286538 -0.021424       9        1   2.743025
# 3      0.212760  0.054345      10        1   1.421674, topic_info=            Term         Freq        Total Category  logprob  loglift
# 242      classes   580.000000   580.000000  Default  30.0000  30.0000
# 16    membership  1075.000000  1075.000000  Default  29.0000  29.0000
# 1090       class   393.000000   393.000000  Default  28.0000  28.0000
# ...

# %%
# 7.4 Commentary
insight("""
Gensim LDA (10 topics, real local run) reproduces the core themes already established by BERTopic
Run 1 and the Stage 7.1 word frequency, while organising them slightly differently:

- Topic 1 (showers, changing, shower, cleaning, dirty, cold, rooms, clean) and Topic 7 (broken, air,
  water, machines, equipment, hot) together reconfirm facilities/cleanliness as the dominant theme —
  consistent with BERTopic Run 1's largest cluster and the original 22% Gensim finding from the
  full-corpus run.
- Topic 3 (classes, class, instructor, cancelled, booked, spin, book) isolates class-booking issues
  more cleanly than BERTopic Run 1 did, where this was folded into a broader "manager conduct" topic.
- Topic 9 (members, puregym, member, staff, management, manager, pt, issues) reconfirms staff/management
  conduct as a standalone theme, echoing the named-staff clusters found in the Stage 5.4 anger-only
  BERTopic re-run.
- Topic 2 (membership, month, cancel, pay, account, money) cleanly isolates cancellation/billing
  friction as its own theme — sharper than its scattered presence across multiple BERTopic Run 1
  clusters.

New finding Gensim surfaced that BERTopic's English-only runs didn't isolate as cleanly: two fully
non-English topics emerged on their own — Topic 5 (er, og, det, ikke, de, der, har, jeg — Danish) and
Topic 8 (und, die, ich, nicht, das, der, ist, es — German). This independently corroborates the
222-review non-English cluster found in the Stage 5.4 anger-only BERTopic re-run, reinforcing that
the project's earlier decision to skip full-corpus language filtering (Stage 2.3: 99.4% English)
likely understated a small but consistent non-English presence concentrated in negative/angry reviews
specifically, since two independent topic-modelling techniques (BERTopic anger-only, and Gensim LDA
on all negative reviews) both isolated it separately.
""")
# Out:
#         <div style="border-left:3px solid #0EA5E9;background:#1E293B;padding:12px 16px;
#                     border-radius:0 6px 6px 0;margin:12px 0">
#           <p style="margin:0;font-family:Inter,sans-serif;font-size:13px;color:#F1F5F9;line-height:1.7">
# Gensim LDA (10 topics, real local run) reproduces the core themes already established by BERTopic
# Run 1 and the Stage 7.1 word frequency, while organising them slightly differently:
#
# - Topic 1 (showers, changing, shower, cleaning, dirty, cold, rooms, clean) and Topic 7 (broken, air,
#   water, machines, equipment, hot) together reconfirm facilities/cleanliness as the dominant theme —
#   consistent with BERTopic Run 1's largest cluster and the original 22% Gensim finding from the
#   full-corpus run.
# - Topic 3 (classes, class, instructor, cancelled, booked, spin, book) isolates class-booking issues
#   more cleanly than BERTopic Run 1 did, where this was folded into a broader "manager conduct" topic.
# ...
