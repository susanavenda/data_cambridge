# %% [markdown]
# **First things first** - please go to 'File' and select 'Save a copy in Drive' so that you have your own version of this demonstration set up and ready to use.

# %% [markdown]
# # Demonstration 2.2.1 Measuring correlation
#
#
# Follow the demonstration to learn how to measure correlation with the Pearson and Spearman methods. In this video, you will learn how to:
# - Perform and interpet Pearson correlation.
# - Perform and interpret Spearman correlation.

# %% [markdown]
# ## a. Create and explore the data set

# %%
# Import the required libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create an expanded data set with more data points.
url = "https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/refs/heads/main/C1W2/weight-height.csv"

# Convert to a Pandas DataFrame.
df = pd.read_csv(url)

# %%
# View the DataFrame.
print(df.shape)
df
# Out:
# (10000, 2)
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
print(df.dtypes)
# Out:
# Height    float64
# Weight    float64
# dtype: object

# %%
# Exploratory data analysis (EDA).
# Descriptive Statistics.
df.describe(include = "all")
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989698

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.scatter(df['Height'],
            df['Weight'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Height')
plt.ylabel('Weight')

# Show the plot.
plt.show()

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.hist(df['Height'],
         color = 'g',
         alpha = 0.7,
         label = 'Height',
         bins = 10)

plt.title('Histogram of height')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.legend()

# Show the plot.
plt.show()

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

plt.hist(df['Weight'],
         color = 'r',
         alpha = 0.7,
         label = 'Weight',
         bins = 10)
plt.title('Histogram of weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.legend()

# Show the plot.
plt.show()

# %% [markdown]
# ## b. Pearson correlation

# %%
# Import the required library.
from scipy.stats import pearsonr

# Calculate Pearson correlation.
pearson_corr, pearson_p_value = pearsonr(df['Height'],
                                         df['Weight'])

# View the output.
print("\nPearson correlation coefficient:", pearson_corr)
print("Pearson p-value:", pearson_p_value)
# Out:
# Pearson correlation coefficient: 0.9247562987378064
# Pearson p-value: 0.0

# %%
# Visualise a heatmap to display the correlation matrix.
plt.figure(figsize=(10, 8))
corr_matrix_pearson = df.corr(method='pearson')

sns.heatmap(corr_matrix_pearson,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"fontsize": 16, "fontweight": "bold"})

plt.title('Pearson correlation')
plt.show()

# %% [markdown]
# ## c. Create and explore the data set

# %%
# Import the data set.
url ='https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/main/thurber.csv'

# Convert to a Pandas DataFrame.
df2 = pd.read_csv(url)

# %%
# View the DataFrame.
print(df2.shape)
df2
# Out:
# (37, 2)
#          y      x
# 0     80.6 -3.070
# 1     84.2 -2.980
# 2     87.3 -2.920
# 3     87.2 -2.910
# 4     89.1 -2.840
# 5     89.6 -2.800
# 6     89.9 -2.700
# 7     90.1 -2.700
# 8     92.4 -2.630
# 9     95.9 -2.480
# 10   101.0 -2.360
# 11   101.0 -2.320
# 12   402.0 -1.500
# 13   391.0 -1.460
# 14   568.0 -1.270
# 15   635.0 -1.210
# 16   733.0 -1.100
# 17   759.0 -1.050
# 18   894.0 -0.915
# 19   991.0 -0.714
# 20  1090.0 -0.566
# 21  1080.0 -0.545
# 22  1120.0 -0.400
# 23  1180.0 -0.309
# 24  1260.0 -0.109
# 25  1270.0 -0.103
# 26  1290.0  0.010
# 27  1330.0  0.119
# 28  1350.0  0.377
# 29  1410.0  0.790
# 30  1430.0  0.963
# 31  1420.0  1.010
# 32  1440.0  1.120
# 33  1460.0  1.570
# 34  1470.0  1.840
# 35  1450.0  2.050
# 36  1460.0  2.200

# %%
print(df2.dtypes)
# Out:
# y    float64
# x    float64
# dtype: object

# %%
# Descriptive Statistics.
df2.describe(include = "all")
# Out:
#                  y          x
# count    37.000000  37.000000
# mean    783.008108  -0.862486
# std     564.118607   1.608742
# min      80.600000  -3.070000
# 25%      95.900000  -2.480000
# 50%     894.000000  -0.915000
# 75%    1330.000000   0.119000
# max    1470.000000   2.200000

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.scatter(df2['x'],
            df2['y'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Predictor variable')
plt.ylabel('Response variable')

# Show the plot.
plt.show()

# %% [markdown]
# ## d. Spearman correlation

# %%
# Import the required library.
from scipy.stats import spearmanr

# Calculate the Spearman correlation.
spearman_corr, spearman_p_value = spearmanr(df2['x'],
                                            df2['y'])

# View the output.
print("\nSpearman correlation coefficient:", spearman_corr)
print("Spearman p-value:", spearman_p_value)
# Out:
# Spearman correlation coefficient: 0.9974509472739708
# Spearman p-value: 9.949797420251718e-42

# %%
# Visualise using a correlation matrix heatmap.
plt.figure(figsize=(10, 8))
corr_matrix_spearman = df2.corr(method='spearman')

sns.heatmap(corr_matrix_spearman,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"fontsize": 16, "fontweight": "bold"})

plt.title('Spearman correlation')

# Show the plot.
plt.show()

# %% [markdown]
# # Key information
# These demonstrations illustrated the importance of measuring Pearson and Spearman correlations. The type of correlation you use to measure correlation will depend on the business scenario and the data set.
#
# ## Reflect
# What are the practical applications of this technique?
#
# > Select the pen from the toolbar to add your entry.
